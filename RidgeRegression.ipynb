# %%
  import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Averaged.csv') #Importing our dataframe

# %%
df.shape #Receiving the size of our dataframe
# Out:
# (23, 27)

# %%
df.size #Receiving the size of our dataframe
# Out:
# 621

# %%
df.ndim
# Out:
# 2

# %%
df.head() #The first five heads of our data frame
# Out:
#                     TEAM         GP          W         L   WINP        MIN  \
# 0         Boston Celtics  10.333333   5.333333  5.000000  0.448  48.300000
# 1          Brooklyn Nets   7.000000   2.666667  4.333333  0.261  48.133333
# 2         Denver Nuggets  14.333333   6.666667  7.666667  0.458  48.900000
# 3        Detroit Pistons   4.000000   0.000000  4.000000  0.000  48.000000
# 4  Golden State Warriors  22.000000  14.000000  8.000000  0.636  48.500000
#
#           PTS        FGM        FGA        FGP  ...       DREB        REB  \
# 0  107.900000  37.566667  85.733333  43.766667  ...  35.200000  44.800000
# 1  109.900000  38.466667  89.633333  42.966667  ...  32.833333  42.433333
# 2  110.433333  40.266667  88.300000  45.700000  ...  32.633333  43.966667
# 3   98.000000  37.500000  96.800000  38.800000  ...  31.500000  42.300000
# 4  114.100000  41.100000  86.100000  47.700000  ...  33.200000  43.300000
#
# ...

# %%
df.drop(['TEAM'], axis = 1) #Dropping the teams column
# Out:
#            GP          W         L      WINP        MIN         PTS  \
# 0   10.333333   5.333333  5.000000  0.448000  48.300000  107.900000
# 1    7.000000   2.666667  4.333333  0.261000  48.133333  109.900000
# 2   14.333333   6.666667  7.666667  0.458000  48.900000  110.433333
# 3    4.000000   0.000000  4.000000  0.000000  48.000000   98.000000
# 4   22.000000  14.000000  8.000000  0.636000  48.500000  114.100000
# 5   11.500000   5.500000  6.000000  0.481000  48.450000  108.100000
# 6    4.000000   0.000000  4.000000  0.000000  48.000000   96.300000
# 7   12.666667   6.333333  6.333333  0.465667  48.133333  113.433333
# 8   16.000000  10.333300  5.666667  0.621000  48.533333  111.400000
# 9    6.000000   2.000000  4.000000  0.314500  48.350000  104.600000
# 10   5.000000   1.000000  4.000000  0.200000  48.000000   99.500000
# 11   9.333333   4.666667  4.666667  0.388667  48.000000  108.500000
# 12   9.000000   3.666667  5.333333  0.344333  49.100000  111.933333
# ...

# %%
df.info() #Receiving the value types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 27 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TEAM     23 non-null     object
#  1   GP       23 non-null     float64
#  2   W        23 non-null     float64
#  3   L        23 non-null     float64
#  4   WINP     23 non-null     float64
#  5   MIN      23 non-null     float64
#  6   PTS      23 non-null     float64
#  7   FGM      23 non-null     float64
#  8   FGA      23 non-null     float64
#  9   FGP      23 non-null     float64
#  10  3PM      23 non-null     float64
#  11  3PA      23 non-null     float64
#  12  3PP      23 non-null     float64
#  13  FTM      23 non-null     float64
#  14  FTA      23 non-null     float64
#  15  FTP      23 non-null     float64
#  16  OREB     23 non-null     float64
#  17  DREB     23 non-null     float64
#  18  REB      23 non-null     float64
#  19  AST      23 non-null     float64
# ...

# %%
df.describe() #Getting the statistical measures of our independent variables
# Out:
#               GP          W          L       WINP        MIN         PTS  \
# count  23.000000  23.000000  23.000000  23.000000  23.000000   23.000000
# mean   10.688406   5.413042   5.275362   0.388870  48.286232  107.074638
# std     5.560572   4.296129   1.449145   0.185721   0.341626    5.388493
# min     4.000000   0.000000   4.000000   0.000000  48.000000   96.300000
# 25%     6.250000   2.250000   4.000000   0.287750  48.000000  104.300000
# 50%     9.333333   4.666667   4.666667   0.391333  48.133333  108.100000
# 75%    13.916667   8.000000   6.000000   0.514250  48.475000  110.916667
# max    22.000000  14.000000   8.000000   0.651500  49.100000  115.000000
#
#              FGM        FGA        FGP        3PM  ...       DREB        REB  \
# count  23.000000  23.000000  23.000000  23.000000  ...  23.000000  23.000000
# mean   38.560145  86.907246  44.408696  11.940580  ...  33.747101  43.417391
# std     2.286874   3.289403   2.389708   1.856016  ...   1.841255   2.278797
# ...

# %%
df.dtypes #Receiving the types of value our independent variable contain
# Out:
# TEAM        object
# GP         float64
# W          float64
# L          float64
# WINP       float64
# MIN        float64
# PTS        float64
# FGM        float64
# FGA        float64
# FGP        float64
# 3PM        float64
# 3PA        float64
# 3PP        float64
# FTM        float64
# FTA        float64
# FTP        float64
# OREB       float64
# DREB       float64
# REB        float64
# AST        float64
# TOV        float64
# STL        float64
# BLK        float64
# BLKA       float64
# PF         float64
# PFD        float64
# POS/NEG    float64
# dtype: object

# %%
df.isnull().sum().sum() #Checking to see if there is any null values
# Out:
# 0

# %%
df.nunique()
# Out:
# TEAM       23
# GP         18
# W          19
# L          12
# WINP       19
# MIN        12
# PTS        23
# FGM        22
# FGA        23
# FGP        23
# 3PM        19
# 3PA        22
# 3PP        22
# FTM        21
# FTA        22
# FTP        23
# OREB       20
# DREB       23
# REB        21
# AST        21
# TOV        21
# STL        20
# BLK        19
# BLKA       22
# PF         22
# PFD        22
# POS/NEG    22
# dtype: int64

# %%
df.corr() #Checking to see the correlations between our variables
# Out:
#                GP         W         L      WINP       MIN       PTS       FGM  \
# GP       1.000000  0.989510  0.903643  0.873092  0.286636  0.465453  0.388461
# W        0.989510  1.000000  0.832290  0.894852  0.261278  0.454490  0.374896
# L        0.903643  0.832290  1.000000  0.697301  0.325278  0.438626  0.379163
# WINP     0.873092  0.894852  0.697301  1.000000  0.290334  0.592239  0.433484
# MIN      0.286636  0.261278  0.325278  0.290334  1.000000  0.380102  0.160347
# PTS      0.465453  0.454490  0.438626  0.592239  0.380102  1.000000  0.842443
# FGM      0.388461  0.374896  0.379163  0.433484  0.160347  0.842443  1.000000
# FGA     -0.230707 -0.255620 -0.127447 -0.332946  0.039587  0.161309  0.417578
# FGP      0.585663  0.586888  0.507385  0.693933  0.142101  0.791208  0.795702
# 3PM      0.168155  0.142803  0.221880  0.178743  0.465537  0.320348 -0.057258
# 3PA      0.068911  0.062893  0.077967  0.094935  0.341445  0.204522 -0.157468
# ...

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix

cols = ['W', 'L', 'PTS', '3PP', 'WINP']

scatterplotmatrix(df[cols].values, figsize=(10, 8), names = cols, alpha = 0.6)
plt.tight_layout()
plt.show() #Plotting the Correlations of our variables

# %%
target_column=['WINP'] #Our target variable
independent_variables=['GP','W','L','WINP','MIN','PTS','FGM','FGA','FGP','3PM','3PA',
            '3PP','FTM','FTA','FTP','OREB','DREB','REB','AST','TOV','STL','BLK','BLKA','PF','PFD','POS/NEG'] #Our independent variable

x=df[independent_variables].values 
y=df[target_column].values

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 10) #The Training and Test Split

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (17, 26)
# (6, 26)
# (17, 1)
# (6, 1)

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha = 1.5) #Initializing our alpha value to change the positioning of the regression line

# %%
ridge.fit(x_train, y_train) #
# Out:
# Ridge(alpha=1.5)

# %%
y_pred = ridge.predict(x_test) #Our prediction values

# %%
y_pred
# Out:
# array([[0.42287887],
#        [0.30011844],
#        [0.50764206],
#        [0.47897601],
#        [0.47711538],
#        [0.35433404]])

# %%
print("Slope: %.2f" % ridge.coef_[0][1]) #The slope
# Out:
# Slope: 0.02

# %%
print("Intercept: %.2f" % ridge.intercept_) #The intercept
# Out:
# Intercept: 0.45

# %%
pred_y_df=pd.DataFrame({'Actual Value': y_test.flatten(), 'Predicted Value': y_pred.flatten(), 'Difference': y_test.flatten()-y_pred.flatten()})
pred_y_df[0:20] #Our predicted values
# Out:
#    Actual Value  Predicted Value  Difference
# 0      0.481000         0.422879    0.058121
# 1      0.261000         0.300118   -0.039118
# 2      0.465667         0.507642   -0.041975
# 3      0.458000         0.478976   -0.020976
# 4      0.388667         0.477115   -0.088449
# 5      0.344333         0.354334   -0.010001

# %%
#Graphing our data points.

import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted')

# %%
import math #The metrics

print("Metrics: ")

from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("R-Squared: ", r2)

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error: ",mse)

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error: ",mae)

from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error: ",mape)
print()
rmse = math.sqrt(mse)
print("The Root Mean Squared Error: ", rmse)

rmae = math.sqrt(mae)
print("The Root Mean Absolute Error: ", rmae)

rmape = math.sqrt(mape)
print("The Root Mean Absolute Percentage Error: ", rmape)
# Out:
# Metrics:
# R-Squared:  0.5913165833190335
# Mean Squared Error:  0.0025055724415104755
# Mean Absolute Error:  0.043106732927481246
# Mean Absolute Percentage Error:  0.11054431527971885
#
# The Root Mean Squared Error:  0.050055693397559435
# The Root Mean Absolute Error:  0.20762160997227924
# The Root Mean Absolute Percentage Error:  0.33248205256783236
